# %%
#pandas

# %%
import pandas as pd

# %%
data=pd.read_csv('fake_customer.csv')
data
# Out:
#      CustomerID           Name    Age  Gender                      Email  \
# 0      CUST1000     Ali Hassan   72.0     NaN       ali.hassan@gmail.com
# 1      CUST1001      Fatma Ali    NaN  Female      fatma.ali@hotmail.com
# 2      CUST1002  Ahmed Mahmoud   -1.0    male  ahmed.mahmoud@hotmail.com
# 3      CUST1003    Ahmed Gaber   -1.0       F      ahmed.gaber@gmail.com
# 4      CUST1004    Ali Ibrahim   73.0       M      ali.ibrahim@yahoo.com
# ...         ...            ...    ...     ...                        ...
# 2145   CUST1447   Mark Mahmoud   66.0    male   mark.mahmoud@hotmail.com
# 2146   CUST1381   Fatma Hassan    NaN       M     fatma.hassan@yahoo.com
# 2147   CUST2338      Ali Gaber   -1.0       M        ali.gaber@gmail.com
# 2148   CUST1694       John Ali  200.0  Female         john.ali@yahoo.com
# 2149   CUST1567   Ahmed Hassan    NaN    male     ahmed.hassan@yahoo.com
#
#             Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2150 entries, 0 to 2149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2150 non-null   object
#  1   Name             2150 non-null   object
#  2   Age              1630 non-null   float64
#  3   Gender           1877 non-null   object
#  4   Email            2150 non-null   object
#  5   Phone            1072 non-null   float64
#  6   PurchaseAmount   2049 non-null   float64
#  7   PurchaseDate     2150 non-null   object
#  8   ProductCategory  1573 non-null   object
#  9   Rating           1821 non-null   float64
#  10  Unnamed          0 non-null      float64
#  11    Gender         1877 non-null   object
# dtypes: float64(5), object(7)
# memory usage: 201.7+ KB

# %%
data.head(10)
# Out:
#   CustomerID           Name    Age  Gender                      Email  \
# 0   CUST1000     Ali Hassan   72.0     NaN       ali.hassan@gmail.com
# 1   CUST1001      Fatma Ali    NaN  Female      fatma.ali@hotmail.com
# 2   CUST1002  Ahmed Mahmoud   -1.0    male  ahmed.mahmoud@hotmail.com
# 3   CUST1003    Ahmed Gaber   -1.0       F      ahmed.gaber@gmail.com
# 4   CUST1004    Ali Ibrahim   73.0       M      ali.ibrahim@yahoo.com
# 5   CUST1005   Alaa Ibrahim    NaN       F   alaa.ibrahim@hotmail.com
# 6   CUST1006       Mark Ali   -1.0    male       mark.ali@hotmail.com
# 7   CUST1007    Alaa Hassan  200.0  female    alaa.hassan@hotmail.com
# 8   CUST1008    John Hassan   89.0    Male      john.hassan@yahoo.com
# 9   CUST1009    Fatma Gaber  200.0  Female    fatma.gaber@hotmail.com
#
#          Phone  PurchaseAmount PurchaseDate ProductCategory  Rating  Unnamed  \
# 0  123456789.0          837.31   2023-10-12           Books     3.0      NaN
# ...

# %%
data.sample(12)
# Out:
#      CustomerID          Name    Age  Gender                     Email  \
# 768    CUST1768   Lina Hassan   -1.0       M     lina.hassan@yahoo.com
# 2142   CUST1307  Fatma Hassan    NaN       F    fatma.hassan@gmail.com
# 1052   CUST2052     Ahmed Ali   -1.0    Male     ahmed.ali@hotmail.com
# 1803   CUST2803  Alaa Ibrahim    NaN    Male    alaa.ibrahim@gmail.com
# 861    CUST1861    Lina Smith   24.0       M      lina.smith@gmail.com
# 364    CUST1364  Lina Ibrahim    NaN    Male    lina.ibrahim@gmail.com
# 2038   CUST3038  Ahmed Hassan   49.0    Male    ahmed.hassan@gmail.com
# 916    CUST1916     Ali Gaber  200.0    male     ali.gaber@hotmail.com
# 467    CUST1467  John Mahmoud    NaN  Female    john.mahmoud@yahoo.com
# 1497   CUST2497    Sara Smith   -1.0       M      sara.smith@gmail.com
# 594    CUST1594  John Ibrahim  200.0    male  john.ibrahim@hotmail.com
# 629    CUST1629   Sara Hassan   43.0  Female     sara.hassan@yahoo.com
#
# ...

# %%
data.describe()
# Out:
#                Age         Phone  PurchaseAmount       Rating  Unnamed
# count  1630.000000  1.072000e+03     2049.000000  1821.000000      0.0
# mean     85.180982  5.668417e+08      509.418882     4.183416      NaN
# std      86.794111  4.321530e+08      288.257697     2.871300      NaN
# min      -1.000000  1.234568e+08        5.060000     1.000000      NaN
# 25%      -1.000000  1.234568e+08      263.680000     2.000000      NaN
# 50%      54.000000  9.876543e+08      519.250000     3.000000      NaN
# 75%     200.000000  9.876543e+08      762.910000     5.000000      NaN
# max     200.000000  9.876543e+08      999.560000    10.000000      NaN

# %%
data.isna().sum()
# Out:
# CustomerID            0
# Name                  0
# Age                   0
# Gender              273
# Email                 0
# Phone              1078
# PurchaseAmount      101
# PurchaseDate          0
# ProductCategory     577
# Rating              329
#   Gender            273
# dtype: int64

# %%
data['Age']=data['Age'].replace({
    "UNKnown":0
}

)
# Out:
# /tmp/ipykernel_6382/3451865102.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Age']=data['Age'].replace({

# %%
data['Age']
# Out:
# 0        72.0
# 1         0.0
# 2        -1.0
# 3        -1.0
# 4        73.0
#         ...
# 2145     66.0
# 2146      0.0
# 2147     -1.0
# 2148    200.0
# 2149      0.0
# Name: Age, Length: 2150, dtype: float64

# %%
data['Age']=data['Age'].astype(int)

# %%
data['Age']
# Out:
# 0        72
# 1         0
# 2        64
# 3        64
# 4        73
#        ...
# 2095     36
# 2096    200
# 2097      0
# 2098    200
# 2099    200
# Name: Age, Length: 2100, dtype: int64

# %%
data.drop(columns='Unnamed',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6382/2090915150.py in <cell line: 0>()
# ----> 1 data.drop(columns='Unnamed',inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
data.drop(columns='Gender',inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(50)

# %%
print(data[data.duplicated()])
# Out:
#      CustomerID           Name  Age                     Email        Phone  \
# 2100   CUST2034    Ali Mahmoud   -1   ali.mahmoud@hotmail.com  987654321.0
# 2101   CUST2176    Ali Ibrahim  200     ali.ibrahim@gmail.com  123456789.0
# 2102   CUST1067     Sara Gaber    0      sara.gaber@yahoo.com  123456789.0
# 2103   CUST2330     John Gaber  200      john.gaber@gmail.com          NaN
# 2104   CUST1650   Lina Ibrahim  200  lina.ibrahim@hotmail.com  987654321.0
# 2105   CUST2868   Sara Mahmoud   -1    sara.mahmoud@gmail.com          NaN
# 2106   CUST1986       Sara Ali   90      sara.ali@hotmail.com          NaN
# 2107   CUST1552    Fatma Gaber    0     fatma.gaber@yahoo.com  987654321.0
# 2108   CUST2427  Fatma Mahmoud  200   fatma.mahmoud@gmail.com          NaN
# 2109   CUST2668    Mark Hassan    0     mark.hassan@yahoo.com          NaN
# 2110   CUST2574   Sara Mahmoud   44    sara.mahmoud@yahoo.com  123456789.0
# ...

# %%
data.nunique()
# Out:
# CustomerID         2100
# Name                 48
# Age                  79
# Email               144
# Phone                 2
# PurchaseAmount     1991
# PurchaseDate        860
# ProductCategory       5
# Rating                6
#   Gender              6
# dtype: int64

# %%
data.columns = data.columns.str.strip()

# %%
data['Gender']=data['Gender'].fillna("UNKNoWn")

# %%
data['Gender']
# Out:
# 0       UNKNoWn
# 1        Female
# 2          male
# 3             F
# 4             M
#          ...
# 2145       male
# 2146          M
# 2147          M
# 2148     Female
# 2149       male
# Name: Gender, Length: 2150, dtype: object

# %%
data['Gender'].unique()
# Out:
# array(['UNKNoWn', 'Female', 'male', 'F', 'M', 'female', 'Male'],
#       dtype=object)

# %%
data['Gender']=data['Gender'].replace({
    'F':'Female',
    'M':'Male',
    'male':'Male',
    'female':'Female',

})
data['Gender'].unique()
# Out:
# array(['UNKNoWn', 'Female', 'Male'], dtype=object)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      CustomerID           Name  Age                      Email        Phone  \
# 0      CUST1000     Ali Hassan   72       ali.hassan@gmail.com  123456789.0
# 1      CUST1001      Fatma Ali    0      fatma.ali@hotmail.com          NaN
# 2      CUST1002  Ahmed Mahmoud   -1  ahmed.mahmoud@hotmail.com          NaN
# 3      CUST1003    Ahmed Gaber   -1      ahmed.gaber@gmail.com          NaN
# 4      CUST1004    Ali Ibrahim   73      ali.ibrahim@yahoo.com  987654321.0
# ...         ...            ...  ...                        ...          ...
# 2095   CUST3095       Alaa Ali   36       alaa.ali@hotmail.com  987654321.0
# 2096   CUST3096     Lina Gaber  200       lina.gaber@yahoo.com          NaN
# 2097   CUST3097    Ali Ibrahim    0    ali.ibrahim@hotmail.com  987654321.0
# 2098   CUST3098   Mark Mahmoud  200   mark.mahmoud@hotmail.com  123456789.0
# 2099   CUST3099    Lina Hassan  200      lina.hassan@gmail.com  987654321.0
#
# ...

# %%
data['ProductCategory'].unique()
# Out:
# array(['Books', nan, 'Toys', 'Clothing', 'Home', 'Electronics'],
#       dtype=object)

# %%
data['Age'].describe()
# Out:
# count    2100.000000
# mean       64.552857
# std        83.922885
# min        -1.000000
# 25%        -1.000000
# 50%         0.000000
# 75%       200.000000
# max       200.000000
# Name: Age, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2100 entries, 0 to 2099
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       2100 non-null   object
#  1   Name             2100 non-null   object
#  2   Age              2100 non-null   int64
#  3   Email            2100 non-null   object
#  4   Phone            1043 non-null   float64
#  5   PurchaseAmount   2003 non-null   float64
#  6   PurchaseDate     2100 non-null   object
#  7   ProductCategory  1535 non-null   object
#  8   Rating           1778 non-null   float64
#  9   Gender           2100 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 180.5+ KB

# %%
data['ProductCategory']=data['ProductCategory'].fillna('unknown')

# %%
data.isna().sum()
# Out:
# CustomerID            0
# Name                  0
# Age                   0
# Email                 0
# Phone              1057
# PurchaseAmount       97
# PurchaseDate          0
# ProductCategory       0
# Rating              322
# Gender                0
# dtype: int64

# %%
data.sample(10)
# Out:
#      CustomerID           Name  Age                    Email        Phone  \
# 1543   CUST2543    Ahmed Gaber   -1    ahmed.gaber@yahoo.com          NaN
# 55     CUST1055    Sara Hassan  200    sara.hassan@yahoo.com  987654321.0
# 1035   CUST2035  Fatma Mahmoud   18  fatma.mahmoud@gmail.com          NaN
# 1075   CUST2075        Ali Ali   -1        ali.ali@yahoo.com  987654321.0
# 779    CUST1779    Sara Hassan   -1    sara.hassan@gmail.com  123456789.0
# 1879   CUST2879    Alaa Hassan   -1    alaa.hassan@gmail.com  987654321.0
# 1805   CUST2805     Mark Gaber    0   mark.gaber@hotmail.com          NaN
# 798    CUST1798       Mark Ali   -1       mark.ali@gmail.com          NaN
# 83     CUST1083     Ali Hassan    0     ali.hassan@yahoo.com          NaN
# 1682   CUST2682   Fatma Hassan   -1   fatma.hassan@yahoo.com  123456789.0
#
#       PurchaseAmount PurchaseDate ProductCategory  Rating   Gender
# 1543          118.05   2025-02-25            Toys     NaN   Female
# ...

# %%
data['PurchaseDate'] = pd.to_datetime(data['PurchaseDate'], errors='coerce')

# %%
data['Age'] = data['Age'].apply(
    lambda x: data['Age'].mean() if x < 0 else (0 if x > 100 else x)
)

# %%
data['Age']
# Out:
# 0       72
# 1        0
# 2       64
# 3       64
# 4       73
#         ..
# 2095    36
# 2096     0
# 2097     0
# 2098     0
# 2099     0
# Name: Age, Length: 2100, dtype: int64

# %%
data.isnull().sum()
# Out:
# CustomerID            0
# Name                  0
# Age                   0
# Email                 0
# Phone              1057
# PurchaseAmount       97
# PurchaseDate        118
# ProductCategory       0
# Rating              322
# Gender                0
# dtype: int64

# %%
data['PurchaseAmount'] = data['PurchaseAmount'].fillna(data['PurchaseAmount'].median())

# %%
data.isnull().sum()
# Out:
# CustomerID            0
# Name                  0
# Age                   0
# Email                 0
# Phone              1057
# PurchaseAmount        0
# PurchaseDate        118
# ProductCategory       0
# Rating              322
# Gender                0
# dtype: int64

# %%
data['PurchaseDate'] = pd.to_datetime(data['PurchaseDate'], errors='coerce')

# 2. عندك حلين للقيم الفاضية (الـ NaT):

# الحل الأول: حذف الصفوف اللي مفيهاش تاريخ (لأن التاريخ أساسي في التحليل)
data = data.dropna(subset=['PurchaseDate'])

# الحل الثاني (لو مش عايزة تمسحي داتا): ملء التاريخ الفاضي بأقدم تاريخ أو أحدث تاريخ موجود
# df['PurchaseDate'] = df['PurchaseDate'].fillna(df['PurchaseDate'].mode()[0])

# 3. التأكد من الترتيب (اختياري)
df = data.sort_values(by='PurchaseDate')

print(data['PurchaseDate'].head())
# Out:
# 0   2023-10-12
# 1   2023-02-23
# 2   2023-07-07
# 3   2023-12-30
# 4   2023-12-07
# Name: PurchaseDate, dtype: datetime64[ns]

# %%
data.isna().sum()
# Out:
# CustomerID         0
# Name               0
# Age                0
# Email              0
# Phone              0
# PurchaseAmount     0
# PurchaseDate       0
# ProductCategory    0
# Rating             0
# Gender             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1982 entries, 0 to 2099
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1982 non-null   object
#  1   Name             1982 non-null   object
#  2   Age              1982 non-null   int64
#  3   Email            1982 non-null   object
#  4   Phone            1982 non-null   object
#  5   PurchaseAmount   1982 non-null   float64
#  6   PurchaseDate     1982 non-null   datetime64[ns]
#  7   ProductCategory  1982 non-null   object
#  8   Rating           1982 non-null   float64
#  9   Gender           1982 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 170.3+ KB

# %%
data['Rating'] = data['Rating'].fillna(data['Rating'].median())
# Out:
# /tmp/ipykernel_6382/578829839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rating'] = data['Rating'].fillna(data['Rating'].median())

# %%
data.to_csv('final_cleaned_data.csv', index=False)
